# %% [markdown]
# # K-Means Clustering Template

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd

# %% [markdown]
# ## Importing the dataset
# - customizable to different dataset
# - change X matrix according to the features you want to use to group clusters

# %%
dataset = pd.read_csv('ENTER_THE_NAME_OF_YOUR_DATASET_HERE.csv')
X = dataset.iloc[:, :].values

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters
# - change variable k depending on the maximum number of clusters you want to go up to

# %%
from sklearn.cluster import KMeans
k = 25
wcss = []
for i in range(1, k+1):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, k+1), wcss)
plt.title("The Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-6e0bdee53ad5> in <module>
#       4 for i in range(1, k+1):
#       5     kmeans = KMeans(n_clusters = i, init = 'k-means++')
# ----> 6     kmeans.fit(X)
#       7     wcss.append(kmeans.inertia_)
#       8 plt.plot(range(1, k+1), wcss)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     989             )
#     990
# --> 991         X = self._validate_data(X, accept_sparse='csr',
#     992                                 dtype=[np.float64, np.float32],
#     993                                 order='C', copy=self.copy_x,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %% [markdown]
# ## Training the K-Means model on the dataset
# - manually change n variable according to the most optimal cluster size determined
#     - defaulted to 5

# %%
n = 5
kmeans = KMeans(n_clusters = n, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-501d893b4e87> in <module>
#       1 n = 5
#       2 kmeans = KMeans(n_clusters = n, init = 'k-means++')
# ----> 3 y_kmeans = kmeans.fit_predict(X)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\cluster\_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1103             Index of the cluster each sample belongs to.
#    1104         """
# -> 1105         return self.fit(X, sample_weight=sample_weight).labels_
#    1106
#    1107     def fit_transform(self, X, y=None, sample_weight=None):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     989             )
#     990
# --> 991         X = self._validate_data(X, accept_sparse='csr',
#     992                                 dtype=[np.float64, np.float32],
# ...

# %% [markdown]
# ## Visualising the clusters

# %%
for i in range(1, n+1):
    plt.scatter(X[y_kmeans == i-1, 0], X[y_kmeans == i-1, 1], s = 100, c = [[rd.uniform(0.1, 0.9), rd.uniform(0.1, 0.9), rd.uniform(0.1, 0.9)]], label = f'Cluster {i}')
    
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 150, c = 'black', label = 'Centroids')
plt.title('Clusters Distribution')
plt.xlabel("x")
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-93f4f6722e82> in <module>
#       2     plt.scatter(X[y_kmeans == i-1, 0], X[y_kmeans == i-1, 1], s = 100, c = [[rd.uniform(0.1, 0.9), rd.uniform(0.1, 0.9), rd.uniform(0.1, 0.9)]], label = f'Cluster {i}')
#       3
# ----> 4 plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 150, c = 'black', label = 'Centroids')
#       5 plt.title('Clusters Distribution')
#       6 plt.xlabel("x")
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'
